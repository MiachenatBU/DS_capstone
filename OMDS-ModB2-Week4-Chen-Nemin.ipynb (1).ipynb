# %% [markdown]
# # Week 4 - Univariate Analysis, part 2

# %% [markdown]
# # 1. Lesson - None

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Below are a histogram and boxplot representation of the same data. A pharmacy is keeping a record of the prices of the drugs that it sells, and an administrator wants to know how much the more expensive drugs tend to cost, in the context of the other prices.
#
# Please write a short explanation of the pros and cons of these two representations. Which would you choose? How would you modify the formatting, if at all, to make it more visually interesting, clear, or informative?

# %%
import numpy as np
import pandas as pd

np.random.seed(0)
num_data = 100
data = np.exp(np.random.uniform(size = num_data) * 4)
df = pd.DataFrame(data.T, columns = ["data"])

# %%
print("The 75th percentile is:", df.quantile(q = 0.75))
df.plot.hist()
# Out:
# The 75th percentile is: data    15.457656
# Name: 0.75, dtype: float64
# <Axes: ylabel='Frequency'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
#I will select the histogram. Pros are 1) it shows the overall shape of the distribution (e.g., normal, skewed, bimodal); 2) it highlights frequency of different price ranges;
#Cons are it does not explicitly show outliers or key summary statistics.
#The box plot, on the other hand, provides a summary of key statistics (median, quartiles, minimum, maximum), and identifies outliers, which is useful for detecting expensive drugs.
#However, it lacks the information about frequency of prices within different ranges.

# %% [markdown]
# # 3. Homework - working on your datasets

# %% [markdown]
# This week, you will do the same types of exercises as last week, but you should use your chosen datasets that someone in your class found last semester. (They likely will not be the particular datasets that you found yourself.)
#
# ### Here are some types of analysis you can do:
#
# - Draw histograms and histogram variants for each feature or column.  (Swarm plot, kde plot, violin plot).
#
# - Draw grouped histograms.  For instance, if you have tree heights for both maple and oak trees, you could draw histograms for both.
#
# - Draw a bar plot to indicate total counts of each categorical variable in a given column.
#
# - Find means, medians, and modes.
#
# ### Conclusions:
#
# - Explain what conclusions you would draw from this analysis: are the data what you expect?  Are the data likely to be usable?  If they are not useable, find some new data!
#
# - What is the overall shape of the distribution?  Is it normal, skewed, bimodal, uniform, etc.?
#
# - Are there any outliers present?  (Data points that are far from the others.)
#
# - If there are multiple related histograms, how does the distribution change across different groups?
#
# - What are the minimum and maximum values represented in each histogram?
#
# - How do bin sizes affect the histogram?  Does changing the bin width reveal different patterns in the data?
#
# - Does the distribution appear normal, or does it have a different distribution?

# %%
data = pd.read_csv('CVD_data.csv')

# %%
data.describe()
# Out:
#            DUPERSID       AGEY1X       ADSEX4      PRVEVY1  DIABDXY1_M18  \
# count  6.741000e+03  6616.000000  3499.000000  6688.000000   6655.000000
# mean   2.684728e+09    44.422158     1.547871     1.415072      1.888054
# std    2.747554e+06    23.859820     0.497774     0.492771      0.315324
# min    2.680001e+09     0.000000     1.000000     1.000000      1.000000
# 25%    2.682340e+09    25.000000     1.000000     1.000000      2.000000
# 50%    2.684729e+09    47.000000     2.000000     1.000000      2.000000
# 75%    2.687099e+09    65.000000     2.000000     2.000000      2.000000
# max    2.689506e+09    85.000000     2.000000     2.000000      2.000000
#
#        DIABDXY2_M18    DIABAGY1    DIABAGY2     ANGIDXY1     ANGIDXY2  \
# count   6614.000000  714.000000  699.000000  5443.000000  5375.000000
# mean       1.889779   50.149860   50.067239     1.977770     1.977860
# std        0.313188   15.515859   15.542429     0.147446     0.147151
# min        1.000000   -7.000000   -7.000000     1.000000     1.000000
# 25%        2.000000   40.000000   40.000000     2.000000     2.000000
# 50%        2.000000   51.000000   51.000000     2.000000     2.000000
# 75%        2.000000   61.000000   61.000000     2.000000     2.000000
# max        2.000000   85.000000   85.000000     2.000000     2.000000
#
#           ARTHDXY1     ARTHDXY2      CHDDXY1      CHDDXY2       MIDXY1  \
# count  5444.000000  5376.000000  5441.000000  5373.000000  5444.000000
# mean      1.697832     1.699219     1.936041     1.936162     1.954629
# std       0.459240     0.458640     0.244702     0.244486     0.208136
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       1.000000     1.000000     2.000000     2.000000     2.000000
# 50%       2.000000     2.000000     2.000000     2.000000     2.000000
# 75%       2.000000     2.000000     2.000000     2.000000     2.000000
# max       2.000000     2.000000     2.000000     2.000000     2.000000
#
#             MIDXY2      TOTTCHY1      TOTTCHY2
# count  5375.000000  6.688000e+03  6.632000e+03
# mean      1.955349  1.761265e+04  1.742381e+04
# std       0.206556  5.786519e+04  5.488162e+04
# min       1.000000  0.000000e+00  0.000000e+00
# 25%       2.000000  6.097500e+02  4.830000e+02
# 50%       2.000000  2.870000e+03  2.590500e+03
# 75%       2.000000  1.074125e+04  1.143200e+04
# max       2.000000  1.742563e+06  1.304094e+06

# %%
data.mode(numeric_only=True).iloc[0]
# Out:
# DUPERSID        2.680001e+09
# AGEY1X          8.500000e+01
# ADSEX4          2.000000e+00
# PRVEVY1         1.000000e+00
# DIABDXY1_M18    2.000000e+00
# DIABDXY2_M18    2.000000e+00
# DIABAGY1        5.000000e+01
# DIABAGY2        5.000000e+01
# ANGIDXY1        2.000000e+00
# ANGIDXY2        2.000000e+00
# ARTHDXY1        2.000000e+00
# ARTHDXY2        2.000000e+00
# CHDDXY1         2.000000e+00
# CHDDXY2         2.000000e+00
# MIDXY1          2.000000e+00
# MIDXY2          2.000000e+00
# TOTTCHY1        0.000000e+00
# TOTTCHY2        0.000000e+00
# Name: 0, dtype: float64

# %%
data[["DIABDXY1_M18", "DIABDXY2_M18"]].value_counts()
# Out:
# DIABDXY1_M18  DIABDXY2_M18
# 2.0           2.0             5849
# 1.0           1.0              729
# Name: count, dtype: int64

# %%
data[["ADSEX4"]].value_counts()
# Out:
# ADSEX4
# 2.0       1917
# 1.0       1582
# Name: count, dtype: int64

# %%
import seaborn as sns
g = sns.FacetGrid(data, col="DIABDXY1_M18", sharey=False)
g.map(sns.histplot, "TOTTCHY1", bins=2000)
g.set(xlim=(0, 20000)) 
g.fig.suptitle("Distribution of total healthcare costs by diabetes diagnosis", fontsize=16, y=1.05)
# Out:
# Text(0.5, 1.05, 'Distribution of total healthcare costs by diabetes diagnosis')

# %%
g = sns.FacetGrid(data, col="ANGIDXY1", sharey=False)
g.map(sns.histplot, "TOTTCHY1", bins=1000)
g.set(xlim=(0, 20000)) 
g.fig.suptitle("Distribution of total healthcare costs by angina diagnosis", fontsize=16, y=1.05)
# Out:
# Text(0.5, 1.05, 'Distribution of total healthcare costs by angina diagnosis')

# %%
g = sns.FacetGrid(data, col="CHDDXY1", sharey=False)
g.map(sns.histplot, "TOTTCHY1", bins=1000)
g.set(xlim=(0, 20000)) 
g.fig.suptitle("Distribution of total healthcare costs by coronary heart disease diagnosis", fontsize=16, y=1.05)
# Out:
# Text(0.5, 1.05, 'Distribution of total healthcare costs by coronary heart disease diagnosis')

# %%
g = sns.FacetGrid(data, col="MIDXY1", sharey=False)
g.map(sns.histplot, "TOTTCHY1", bins=1000)
g.set(xlim=(0, 20000)) 
g.fig.suptitle("Distribution of total healthcare costs by heart attack diagnosis", fontsize=16, y=1.05)
# Out:
# Text(0.5, 1.05, 'Distribution of total healthcare costs by heart attack diagnosis')

# %%
#Age at diabetes diagnosis
data_plot1 = data[['DIABAGY1', 'DIABAGY2']]
data_plot1[data_plot1['DIABAGY1'] < 0] = np.nan
data_plot1[data_plot1['DIABAGY2'] < 0] = np.nan
data_plot1.hist()
# Out:
# /tmp/ipykernel_4325/3627444273.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_plot1[data_plot1['DIABAGY1'] < 0] = np.nan
# /tmp/ipykernel_4325/3627444273.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_plot1[data_plot1['DIABAGY1'] < 0] = np.nan
# /tmp/ipykernel_4325/3627444273.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_plot1[data_plot1['DIABAGY2'] < 0] = np.nan
# /tmp/ipykernel_4325/3627444273.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_plot1[data_plot1['DIABAGY2'] < 0] = np.nan
# array([[<Axes: title={'center': 'DIABAGY1'}>,
#         <Axes: title={'center': 'DIABAGY2'}>]], dtype=object)

# %%
#age at diabetes diagnosis by gender
data_plot2 = data[['DIABAGY1', 'ADSEX4']]
data_plot2[data_plot2['DIABAGY1'] < 0] = np.nan
data_plot2[data_plot2['ADSEX4'] < 0] = np.nan

g = sns.FacetGrid(data_plot2, col="ADSEX4")
g.map(sns.histplot, "DIABAGY1")

#The average age of diabetes diagnosis was similar between male and female.
# Out:
# /tmp/ipykernel_2088/2916269681.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_plot2[data_plot2['DIABAGY1'] < 0] = np.nan
# /tmp/ipykernel_2088/2916269681.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_plot2[data_plot2['ADSEX4'] < 0] = np.nan

# %%
#have prvate insurabce among patients with diabetes diagnosis
data_plot3 = data[['PRVEVY1', 'DIABDXY1_M18']]
data_plot3 = data_plot3[data_plot3['DIABDXY1_M18']==1]

sns.countplot(x="PRVEVY1", data=data_plot3)
# Out:
# <Axes: xlabel='PRVEVY1', ylabel='count'>

# %%
data_plot4 = data[['DIABAGY1', 'TOTTCHY1', 'TOTTCHY2', 'DIABDXY1_M18']]
data_plot4 = data_plot4[data_plot4['DIABDXY1_M18']==1]
data_plot4[data_plot4['DIABAGY1'] < 0] = np.nan
 
data_plot4.mode(numeric_only=True).iloc[0]
# Out:
# DIABAGY1        50.0
# TOTTCHY1         0.0
# TOTTCHY2         0.0
# DIABDXY1_M18     1.0
# Name: 0, dtype: float64

# %%
data_plot4.describe()
#The means, medians, and modes for age at diabetes diagnosis are 50.2, 51.0, and 50.0;
#The means, medians, and modes for total medical charges in 2021 are 37253, 8463, and 0;
#The means, medians, and modes for total medical charges in 2022 are 43300, 8551, and 0.
# Out:
#          DIABAGY1       TOTTCHY1      TOTTCHY2  DIABDXY1_M18
# count  713.000000     713.000000  7.130000e+02         713.0
# mean    50.230014   37252.039271  4.330012e+04           1.0
# std     15.378113   85312.693456  1.079485e+05           0.0
# min      0.000000       0.000000 -1.000000e+00           1.0
# 25%     40.000000    2148.000000  2.080000e+03           1.0
# 50%     51.000000    8463.000000  8.551000e+03           1.0
# 75%     61.000000   27752.000000  3.868500e+04           1.0
# max     85.000000  930933.000000  1.304094e+06           1.0

# %%
#conclusions:
#The age at diabetes diagnosis distribution is normally distrbuted

#No outliers were observed. 

#The distributions of age at diabetes diagnosis are similar between male and female. 

# The minimum and maximum values of age at diabetes diagnosis are 0 and 82 for male and 0 and 85 for female. 

# Changing the bin width will reveal different patterns in the data.

# %% [markdown]
# # 4. Storytelling With Data graph

# %% [markdown]
# Reproduce any graph of your choice in p. 52-68 of the Storytelling With Data book as best you can.  (The second half of chapter two).  You do not have to get the exact data values right, just the overall look and feel.

# %%
import matplotlib.pyplot as plt
#look at race with horizontal bar chart
race_counts = data["RACEV1X"].value_counts().reset_index()
race_counts.columns = ["Race", "Count"]
plt.barh(race_counts["Race"], race_counts["Count"], color="skyblue")
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Week 7 - Milestone One week

# %% [markdown]
# # 1. Lesson: no lesson this week.  Milestone One is due!

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Below are the graphs from last week's weekly graph question.  Suppose you wanted to cause the viewer to examine the last three months of data first.  How could you use preattentive attributes to do that?  Suggest several possibilities.

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
numdates = 12
np.random.seed(0)
time_series = 100 * (np.random.normal(size = numdates) / 5 + np.arange(numdates) / 16)
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Nitrate level (% of eutrophic value)")
# Out:
# /tmp/ipykernel_2543/2149468501.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Nitrate level (% of eutrophic value)')

# %%
np.random.seed(1)
time_series = 100 * (1 - (np.random.normal(size = numdates) / 8 + np.arange(numdates) / 16))
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Phosphate level (% of eutrophic value)")
# Out:
# /tmp/ipykernel_2543/1012779568.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Phosphate level (% of eutrophic value)')

# %%
#Suggestions to emphasize the last 3 month data:

# 1. Use a bold, high-contrast color (e.g., red or dark blue) for the last three months of data while keeping the earlier months in a neutral or desaturated color (e.g., gray).

# 2. Make the last three months of the trend line thicker than the earlier months to make them stand out.

# 3. Use annotations, arrows, or labels to explicitly draw attention to key trends or anomalies in the last three months.

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you can work on Milestone One rather than having a particular exercise about working on your datasets

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 99-119 of the Storytelling With Data book as best you can. (The first half of chapter four). You do not have to get the exact data values right, just the overall look and feel.

# %%
import matplotlib.pyplot as plt

numdates = 12
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
time_series1 = np.random.random(size = numdates) * 0.01 + np.random.normal(size = numdates) * 2
time_series2 = np.random.random(size = numdates) * 0.01 + np.random.normal(size = numdates) * 3

plt.plot(months, time_series1, label='Time series 1', marker='o', color=(0.2, 0.3, 0.2))

for i in range(-5, 0):  # Last three months indices
    plt.text(months[i], time_series1[i], f'{round(time_series1[i], 2)}', fontsize=12, ha='center', va="bottom", color=(0.2, 0.3, 0.2))

plt.plot(months, time_series2, label='Time series 2', marker='o', color=(0.2, 0.3, 0.4))

for i in range(-5, 0):  # Last three months indices
    plt.text(months[i], time_series2[i], f'{round(time_series2[i], 2)}', fontsize=12, ha='center', va="top", color=(0.2, 0.3, 0.4))
